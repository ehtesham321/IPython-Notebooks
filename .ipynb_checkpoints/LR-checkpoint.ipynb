# %%
import numpy as np
X = 2 * np.random.rand(100,1)

# %%
X_b = np.c_[np.ones((100,1)),X]

# %%
type(X_b.T)
# Out:
# numpy.ndarray

# %%
X_b
# Out:
# array([[ 1.        ,  0.14412851],
#        [ 1.        ,  1.40927109],
#        [ 1.        ,  1.7639971 ],
#        [ 1.        ,  1.81006264],
#        [ 1.        ,  1.69246615],
#        [ 1.        ,  1.56410191],
#        [ 1.        ,  1.37542444],
#        [ 1.        ,  1.68186686],
#        [ 1.        ,  1.4345047 ],
#        [ 1.        ,  1.27464968],
#        [ 1.        ,  0.03772104],
#        [ 1.        ,  1.18277895],
#        [ 1.        ,  0.99414449],
#        [ 1.        ,  0.20433803],
#        [ 1.        ,  1.53753861],
#        [ 1.        ,  0.35100222],
#        [ 1.        ,  1.4817756 ],
#        [ 1.        ,  0.67266686],
#        [ 1.        ,  1.95904904],
#        [ 1.        ,  1.65821129],
#        [ 1.        ,  0.55975128],
#        [ 1.        ,  1.75728789],
#        [ 1.        ,  1.02291621],
#        [ 1.        ,  0.61963953],
#        [ 1.        ,  1.256211  ],
#        [ 1.        ,  0.99761793],
#        [ 1.        ,  0.76233976],
# ...
